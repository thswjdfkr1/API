# %% [markdown]
# # Gemini API 호출

# %%
# !pip install -q -U google-generativeai

# %% [markdown]
# ## import packages

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display, Markdown

# %%
def to_markdown(text):
  text=text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %% [markdown]
# ## setup api key

# %%
# Or use `os.getenv('GOOGLE_API_KEY')` to fetch an environment variable.

GOOGLE_API_KEY="AIzaSyDX--kCXs-j6i6D5mdLFoqmGMA_r-QEwEc"
genai.configure(api_key=GOOGLE_API_KEY)

# %% [markdown]
# ## list model

# %%
for m in genai.list_models():
 if 'generateContent' in m.supported_generation_methods:
  print(m.name)

# List models
# gemini-pro 텍스트 전용 프롬프트에 최적화
# gemini-pro-vision 텍스트와 이미지 프롬프트에 최적화
# Out:
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.5-pro-exp-03-25
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# ...

# %% [markdown]
# ## 텍스트 생성하기

# %%
model = genai.GenerativeModel('gemini-2.0-flash')

# %%
# %%time
reponse = model.generate_content('딤섬 만드는법 알려줘')
# Out:
# CPU times: user 166 ms, sys: 25.8 ms, total: 192 ms
# Wall time: 10.9 s

# %%
reponse
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
# ...

# %%
reponse.text
# Out:
# '딤섬은 종류가 워낙 다양해서 어떤 딤섬을 만들고 싶으신지에 따라 레시피가 달라집니다. 가장 인기 있는 딤섬 몇 가지의 기본 레시피와 팁을 알려드릴게요.\n\n**1. 샤오롱바오 (소룡포): 육즙 가득한 만두**\n\n*   **재료:**\n    *   **돼지고기 소:** 돼지고기 간 것 300g, 다진 생강 1작은술, 다진 파 2큰술, 간장 1큰술, 설탕 1/2작은술, 참기름 1작은술, 소금 약간, 후추 약간, 치킨 스톡 또는 물 1/2컵 (젤라틴을 넣어 굳힌 후 잘게 썰어 넣으면 육즙이 더 풍부해집니다)\n    *   **만두피:** 강력분 200g, 뜨거운 물 100ml, 소금 약간\n*   **만드는 법:**\n    1.  **돼지고기 소 만들기:** 볼에 돼지고기 간 것을 넣고 생강, 파, 간장, 설탕, 참기름, 소금, 후추를 넣고 잘 섞어줍니다. 치킨 스톡 또는 물을 조금씩 넣으면서 반죽이 부드러워질 때까지 섞어줍니다. 젤라틴을 넣을 경우 잘게 썰어 넣고 섞어줍니다.\n    2.  **만두피 만들기:** 볼에 강력분과 소금을 넣고 뜨거운 물을 조금씩 부으면서 반죽합니다. 반죽이 어느 정도 뭉쳐지면 손으로 10분 정도 치대어 매끄러운 반죽을 만듭니다. 반죽을 젖은 천으로 덮어 30분 정도 숙성시킵니다.\n    3.  **만두 빚기:** 숙성된 반죽을 가늘게 늘려 자른 후, 밀대로 얇게 밀어 만두피를 만듭니다. 만두피 가운데에 돼지고기 소를 넣고 주름을 잡아가며 빚어줍니다.\n    4.  **찌기:** 찜기에 물을 붓고 끓으면 샤오롱바오를 넣고 10-12분 정도 쪄줍니다.\n*   **팁:**\n    *   샤오롱바오의 핵심은 육즙입니다. 치킨 스톡이나 젤라틴을 넣어 육즙을 풍부하게 만들어보세요.\n    *   만두피를 너무 두껍게 만들면 식감이 좋지 않으니 최대한 얇게 밀어주세요.\n    *   쪄낸 후 바로 드시면 입 안에서 육즙이 터져 나오는 맛을 제대로 즐길 수 있습니다.\n\n**2. 하가우 (새우 만두): 투명한 만두피가
# ...

# %%
to_markdown(response.text)
# Out:
# > 딤섬은 종류가 워낙 다양해서 어떤 딤섬을 만들고 싶으신지에 따라 레시피가 달라집니다. 가장 인기 있는 딤섬 몇 가지의 기본 레시피와 팁을 알려드릴게요.
# >
# > **1. 샤오롱바오 (소룡포): 육즙 가득한 만두**
# >
# > *   **재료:**
# >     *   **돼지고기 소:** 돼지고기 간 것 300g, 다진 생강 1작은술, 다진 파 2큰술, 간장 1큰술, 설탕 1/2작은술, 참기름 1작은술, 소금 약간, 후추 약간, 치킨 스톡 또는 물 1/2컵 (젤라틴을 넣어 굳힌 후 잘게 썰어 넣으면 육즙이 더 풍부해집니다)
# >     *   **만두피:** 강력분 200g, 뜨거운 물 100ml, 소금 약간
# > *   **만드는 법:**
# >     1.  **돼지고기 소 만들기:** 볼에 돼지고기 간 것을 넣고 생강, 파, 간장, 설탕, 참기름, 소금, 후추를 넣고 잘 섞어줍니다. 치킨 스톡 또는 물을 조금씩 넣으면서 반죽이 부드러워질 때까지 섞어줍니다. 젤라틴을 넣을 경우 잘게 썰어 넣고 섞어줍니다.
# >     2.  **만두피 만들기:** 볼에 강력분과 소금을 넣고 뜨거운 물을 조금씩 부으면서 반죽합니다. 반죽이 어느 정도 뭉쳐지면 손으로 10분 정도 치대어 매끄러운 반죽을 만듭니다. 반죽을 젖은 천으로 덮어 30분 정도 숙성시킵니다.
# >     3.  **만두 빚기:** 숙성된 반죽을 가늘게 늘려 자른 후, 밀대로 얇게 밀어 만두피를 만듭니다. 만두피 가운데에 돼지고기 소를 넣고 주름을 잡아가며 빚어줍니다.
# >     4.  **찌기:** 찜기에 물을 붓고 끓으면 샤오롱바오를 넣고 10-12분 정도 쪄줍니다.
# > *   **팁:**
# >     *   샤오롱바오의 핵심은 육즙입니다. 치킨 스톡이나 젤라틴을 넣어 육즙을 풍부하게 만들어보세요.
# >     *   만두피를 너무 두껍게 만들면 식감이 좋지 않으니 최대한 얇게 밀어주세요.
# ...

# %%
response.prompt_feedback

# %% [markdown]
# Gemini는 하나의 프롬프트에 대해 여러 개의 가능한 응답을 생성할 수 있다
# 가능한 응답을 candidates라고 하며 이를 검토하여 가장 적합한 응답을 선택할 수 있다
#
# GenerateContentResponse.candidates 응답 후보

# %%
response.candidates
# Out:
# [content {
#   parts {
# ...

# %% [markdown]
# ## generation config

# %%
generation_config = {
    'temperature': 0.9,
    'max_output_tokens': 1024
}

# %%
# %%time
response = model.generate_content('삶이란 뭘까?', generation_config=generation_config)
# Out:
# CPU times: user 65.8 ms, sys: 7.88 ms, total: 73.7 ms
# Wall time: 4.04 s

# %%
to_markdown(response.text)
# Out:
# > 삶이란 무엇인지에 대한 질문은 인류 역사상 가장 오랫동안 논의되어 온 심오하고 복잡한 질문입니다. 철학, 종교, 과학, 개인적인 경험 등 다양한 관점에서 접근할 수 있으며, 정답은 하나로 정의하기 어렵습니다.
# >
# > **다양한 관점:**
# >
# > *   **생물학적 관점:** 생명체로서 태어나 성장하고, 번식하며, 늙고 죽는 과정입니다. 유전자를 전달하고 종을 유지하는 활동이라고 볼 수 있습니다.
# > *   **철학적 관점:** 존재의 의미, 가치, 목적을 탐구하는 여정입니다. 행복, 고통, 자유, 책임 등 다양한 개념을 고민하며 자신만의 답을 찾아가는 과정입니다.
# > *   **종교적 관점:** 신 또는 초월적인 존재와의 관계 속에서 의미를 찾고, 영적인 성장과 구원을 추구하는 과정입니다.
# > *   **개인적 관점:** 각 개인이 경험하고 느끼는 모든 것입니다. 사랑, 슬픔, 기쁨, 분노 등 감정, 관계, 경험, 기억, 가치관 등이 삶을 구성합니다.
# >
# > **삶에 대한 다양한 정의:**
# >
# > *   **과정:** 삶은 탄생에서 죽음까지 이어지는 끊임없는 변화와 성장의 과정입니다.
# > *   **경험:** 삶은 세상과 상호작용하며 다양한 경험을 쌓아가는 과정입니다.
# > *   **선택:** 삶은 매 순간 선택의 연속이며, 자신의 선택에 따라 삶의 방향이 결정됩니다.
# > *   **관계:** 삶은 타인과의 관계 속에서 의미를 찾고, 서로 영향을 주고받는 과정입니다.
# > *   **의미:** 삶은 자신만의 의미와 목적을 찾아 실현해 나가는 과정입니다.
# >
# > **스스로에게 질문해 보세요:**
# >
# > *   나에게 삶이란 무엇인가?
# > *   나는 무엇을 중요하게 생각하는가?
# > *   나는 어떤 삶을 살고 싶은가?
# > *   나의 삶의 목적은 무엇인가?
# >
# > 이러한 질문들을 스스로에게 던져보고 고민하는 과정에서 자신만의 삶의 의미를 찾아갈 수 있을 것입니다.
# >
# ...

# %% [markdown]
# ## streaming

# %% [markdown]
# 기본적으로 모델은 전체 생성 프로세스를 완료한 후 응답을 반환
# 응답이 생성되는 동안 응답을 스트리밍할 수 있으며 모델은 응답이 생성되는 즉시 청크를 반환
#
# 응답을 스트리밍하려면 `GenerativeModel.generate_content(..., stream=True)

# %%
# %%time
response = model.generate_content('삶의 의미가 뭘까?', stream=True)
# Out:
# CPU times: user 61.8 ms, sys: 8.97 ms, total: 70.8 ms
# Wall time: 3.37 s

# %%
for chunk in response:
  print(chunk.text)
  print("_"*80)
# Out:
# 삶
# ________________________________________________________________________________
# 의 의미는
# ________________________________________________________________________________
#  참 어려운 질문이죠. 정답이 정해져 있는 것도 아니고, 사람
# ________________________________________________________________________________
# 마다 다르게 느낄 수 있는 주관적인 것이니까요.
#
# 어
# ________________________________________________________________________________
# 떤 사람들은 삶의 의미를 **관계**에서 찾기도 해요. 가족, 친구, 연인과의 사랑과 유대감 속에서 행복을 느끼
# ________________________________________________________________________________
# 고 살아가는 거죠. 또 다른 사람들은 **성장**을 통해 의미를 찾아요. 새로운 것을 배우고, 능력을 개발하고, 꿈을 이루어 나가
# ________________________________________________________________________________
# 면서 삶의 가치를 발견하는 거죠.
#
# **사회에 기여**하는 것에서 삶의 의미를 찾는 사람들도 많아요. 봉사활동을 하거나, 환경을 보호하거나, 사회 문제 해결에 힘쓰면서 세상에
# ________________________________________________________________________________
# ...

# %%
for chunk in response:
  print(chunk.text, end="")
# Out:
# 삶의 의미는 참 어려운 질문이죠. 정답이 정해져 있는 것도 아니고, 사람마다 다르게 느낄 수 있는 주관적인 것이니까요.
#
# 어떤 사람들은 삶의 의미를 **관계**에서 찾기도 해요. 가족, 친구, 연인과의 사랑과 유대감 속에서 행복을 느끼고 살아가는 거죠. 또 다른 사람들은 **성장**을 통해 의미를 찾아요. 새로운 것을 배우고, 능력을 개발하고, 꿈을 이루어 나가면서 삶의 가치를 발견하는 거죠.
#
# **사회에 기여**하는 것에서 삶의 의미를 찾는 사람들도 많아요. 봉사활동을 하거나, 환경을 보호하거나, 사회 문제 해결에 힘쓰면서 세상에 긍정적인 영향을 주는 것이죠. 혹은 **자신만의 가치**를 실현하는 것에서 의미를 찾을 수도 있어요. 예술 활동을 하거나, 사업을 하거나, 자신만의 철학을 가지고 살아가는 것이죠.
#
# 삶의 의미를 찾는 방법은 정말 다양하지만, 중요한 건 **자신에게 맞는 의미**를 찾는 것이라고 생각해요. 스스로에게 끊임없이 질문하고, 다양한 경험을 해보면서 자신만의 답을 찾아가는 과정이 중요하죠.
#
# 혹시 지금 어떤 점 때문에 삶의 의미에 대해 고민하고 계신가요? 좀 더 구체적으로 이야기해주시면 함께 생각해볼 수 있을 것 같아요. 예를 들어 "요즘 하는 일에 흥미를 못 느껴서 삶이 무의미하게 느껴진다" 와 같이 말씀해주시면, 좀 더 현실적인 조언을 드릴 수 있을 것 같아요.

# %% [markdown]
# ## Chat conversations
#
# Gemini를 사용하면 여러 차례에 걸쳐 자유로운 형식의 대화를 할 수 있다
# ChatSession 클래스는 대화의 상태를 관리하여 프로세스를 간소화하므로 generate_content와 달리 대화 기록을 목록으로 저장할 필요가 없다

# %%
model = genai.GenerativeModel('gemini-2.0-flash')
chat = model.start_chat(history=[])
chat
# Out:
# ChatSession(
#     model=genai.GenerativeModel(
#         model_name='models/gemini-2.0-flash',
#         generation_config={},
#         safety_settings={},
#         tools=None,
#         system_instruction=None,
#         cached_content=None
#     ),
#     history=[]
# )

# %% [markdown]
# `ChatSession.send_message` 메서드는 `GenerativeModel.generate_content`와 동일한 `GenerateContentResponse` 유형을 반환
# 또한 메시지와 응답을 채팅 기록에 추가

# %%
response = chat.send_message('어린 아이에게 컴퓨터가 어떻게 작동하는지 한 문장으로 알려줘')
to_markdown(response.text)
# Out:
# > 컴퓨터는 네가 원하는 것을 할 수 있도록 도와주는 아주 똑똑한 상자인데, 네가 명령하는 대로 생각하고 계산하고 기억할 수 있어!

# %%
chat.history
# Out:
# [parts {
#    text: "어린 아이에게 컴퓨터가 어떻게 작동하는지 한 문장으로 알려줘"
#  }
#  role: "user",
#  parts {
#    text: "컴퓨터는 네가 원하는 것을 할 수 있도록 도와주는 아주 똑똑한 상자인데, 네가 명령하는 대로 생각하고 계산하고 기억할 수 있어!\n"
#  }
#  role: "model"]

# %%
response = chat.send_message("고등학생 수준으로 설명해줘", stream=True)

for chunk in response:
  print(chunk.text)
  print("_"*80)
# Out:
# 컴
# ________________________________________________________________________________
# 퓨터는
# ________________________________________________________________________________
#  전기 신호를 이용하여 정보를 처리하고 저장하는 복잡한 기계로, 중앙
# ________________________________________________________________________________
#  처리 장치(CPU)가 연산을 수행하고 메모리(RAM)가
# ________________________________________________________________________________
#  데이터를 임시 저장하며, 저장 장치(SSD/HDD)는 데이터를 영구적으로 보관하고, 이 모든 것이 운영체제(OS)라는 소프트웨어
# ________________________________________________________________________________
# 에 의해 제어됩니다.
#
# ________________________________________________________________________________

# %%
for message in chat.history:
  display(to_markdown(f'**{message.role}**: {message.parts[0].text}'))
# Out:
# > **user**: 어린 아이에게 컴퓨터가 어떻게 작동하는지 한 문장으로 알려줘
# > **model**: 컴퓨터는 네가 원하는 것을 할 수 있도록 도와주는 아주 똑똑한 상자인데, 네가 명령하는 대로 생각하고 계산하고 기억할 수 있어!
# > **user**: 고등학생 수준으로 설명해줘
# > **model**: 컴퓨터는 전기 신호를 이용하여 정보를 처리하고 저장하는 복잡한 기계로, 중앙 처리 장치(CPU)가 연산을 수행하고 메모리(RAM)가 데이터를 임시 저장하며, 저장 장치(SSD/HDD)는 데이터를 영구적으로 보관하고, 이 모든 것이 운영체제(OS)라는 소프트웨어에 의해 제어됩니다.

# %% [markdown]
# count tokens

# %%
model.count_tokens('ai가 뭔지 한문장으로 설명해줘')
# Out:
# total_tokens: 11

# %%
model.count_tokens(chat.history)
# Out:
# total_tokens: 144
